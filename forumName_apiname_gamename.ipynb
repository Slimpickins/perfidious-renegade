# %%
import pandas as pd 
import json
import requests
import time
import csv
from pandas import Series, DataFrame

# %%
#Getting the member list from daybreak

call = 'https://census.daybreakgames.com/get/ps2:v2/outfit/?outfit_id=37530159341115681&c:resolve=member_character(name)'
resp = requests.get(url=call)
temp = resp.json()
#df = pd.read_json('https://census.daybreakgames.com/get/ps2:v2/outfit/?outfit_id=37530159341115681&c:resolve=member_character(name)')

# %%
# Filtering to get only the members
# We have raw data if you want to get a new memberlist with current data start again here
members =  temp['outfit_list'][0]
data = members["members"][0:]
nameDF = DataFrame.from_dict(data)

#Expanding 'name' column dictionary to return only 'first_lower' name.
nameDF2 = nameDF['name'].apply(Series)
nameDF2.drop(nameDF2.columns[[0,2]], inplace=True, axis=1)
nameDF.drop('name', inplace=True, axis=1)
nameDF['name'] = nameDF2[[0]]

nameDF.head()
#nameDF.to_csv('aodmems.csv', index=False)
# Out:
#           character_id member_since      member_since_date         rank  \
# 0  5428163811557775809   1478569080  2016-11-08 01:38:00.0  Prospective
# 1  5428351605420268353   1478569081  2016-11-08 01:38:01.0  Prospective
# 2  5428533594990100497   1478569082  2016-11-08 01:38:02.0  Prospective
# 3  5428533594970462289   1478569085  2016-11-08 01:38:05.0  Prospective
# 4  5428345446430441233   1479000326  2016-11-13 01:25:26.0  Prospective
#
#   rank_ordinal            name
# 0            5      ishcabob20
# 1            5       encryyptt
# 2            5     legobryson5
# 3            5    loukabertant
# 4            5  thebrownmanjr1

# %%
#Run this if you want only full-members. 'rank ordinal' values are 1-5, 5 being all members 1 being leader,
# so NCOs start at 3
nameDF = nameDF[nameDF['rank_ordinal'].astype('float') <5]
nameDF.head()
nameDF.to_csv('aodfullmems.csv', index=False)

# %%
nameDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 706 entries, 12 to 8337
# Data columns (total 6 columns):
# character_id         706 non-null object
# member_since         706 non-null object
# member_since_date    706 non-null object
# rank                 706 non-null object
# rank_ordinal         706 non-null object
# name                 706 non-null object
# dtypes: object(6)
# memory usage: 38.6+ KB

# %%
#creates a downloadable file of the members list generated

# %%
#oldmembersList =
#newmembersList =
colsNames = ['Name','Rank','Game','Status', 'Join Date', 'Last Activity']
oldRoster = 'https://docs.google.com/spreadsheets/d/1K4C6GG6PJeeIvdQ2trlectVmFX5TktEjG6Vz9jMmMnk/pub?gid=0&single=true&output=csv'
oldMembersList = pd.read_csv(oldRoster, names=colsNames)

#oldMembersList.dropna(inplace=True)
#oldMembersList = oldMembersList.ix[~(oldMembersList['Name'] == 'User')]
#oldMembersList = oldMembersList.ix[oldMembersList[2] == 'PlanetSide 2']
newRoster = 'https://docs.google.com/spreadsheets/d/1461AUqTAHpBjxAhTB3hAZt-JPZQOpeh9OxgorEnhbDk/pub?gid=0&single=true&output=csv'
newShowRoster = pd.read_csv(newRoster, names=colsNames)
newShowRoster.dropna(inplace=True)
newShowRoster = newShowRoster.ix[~(newShowRoster['Name'] == 'User')]
#newShowRoster = newShowRoster.ix[newShowRoster[2] == 'PlanetSide 2']
#print('----Old Roster----')
#oldMembersList.head()
#print('----New Roster----')
#newShowRoster.head()
#oldMembersList.head()

# %%
# Master List of 'fullmembers' that have been in AODR
# Return names from the 'fullmembers' and if they are in planetside 2
# newRoster vlookup to the fullmembers database
forumName_gameName = 'https://docs.google.com/spreadsheets/d/1eqto1dUrp59LyONB2ZUh3mSSzeLepOiT2nyDMarN3lU/pub?gid=75908457&single=true&output=csv'
forumGameName = pd.read_csv(forumName_gameName, names = ['Name', 'GameName'])

# %%
forumGameName = forumGameName
newShowRoster1 = newShowRoster

# %%
# dont mess with this celll again
newShowRoster = newShowRoster1.merge(forumGameName, how='outer')
#newShowRoster = newShowRoster.merge(forumGameName[['Name','GameName']], on=['Name'], indicator=False)

# %%
#newShowRoster2.info()
#newShowRoster.to_csv('meeb.csv')

# %%
#newShowRoster1 = newShowRoster1.merge(nameDF['GameName'], on=['GameName'], how='outer')
#newShowRoster1 
#newShowRoster.GameName = newShowRoster.apply( lambda x: x.astype(str).str.lower())
#newShowRoster.apply( lambda x: x.astype(str).str.lower())
#newShowRoster1 = newShowRoster1.merge(forumGameName[['Name','GameName']], on=['Name'], indicator=False)
newShowRoster['GameName'] = newShowRoster.GameName.astype(str).str.lower()
#newShowRoster2.head()

# Okay so we now have a combined list of all members and their ingame name from the masterList

# %%
#return all the people with a planetside 2 name or are in planetside 2 division

newShowRoster1 = newShowRoster[(newShowRoster['GameName']!='nan') |
                                (newShowRoster['Game']== 'PlanetSide 2')]
newShowRoster = newShowRoster1.dropna(thresh=3)

# %%
#newShowRoster4.head(55)
#newShowRoster4.info()

# %%
newShowRoster.head(55)
# Out:
#                               Name                 Rank          Game  \
# 530               AOD_RenegadeEcho                Cadet   Battlefield
# 566              AOD_SmokingBarrel                Cadet   Battlefield
# 837                 AOD_RedneckSOD              Recruit  Black Desert
# 1039                 AOD_adeadhead                Cadet     Overwatch
# 1185                AOD_Mikearuant  Private First Class     Overwatch
# 1248              AOD_ShadowSheeps              Private     Overwatch
# 1310                    AOD_0znex0              Recruit  PlanetSide 2
# 1311                     AOD_2k301                Cadet  PlanetSide 2
# 1312                AOD_308shooter              Recruit  PlanetSide 2
# 1313               AOD_3423Collins  Private First Class  PlanetSide 2
# 1314               AOD_408THUGLIFE              Recruit  PlanetSide 2
# 1315                 AOD_40ozMouse  Private First Class  PlanetSide 2
# 1316                  AOD_Abandons              Recruit  PlanetSide 2
# 1317                     AOD_Abocs              Recruit  PlanetSide 2
# 1318             AOD_AchesAndPains              Private  PlanetSide 2
# 1319                  AOD_Adapt1ve             Sergeant  PlanetSide 2
# 1320            AOD_AdmiralStryker              Recruit  PlanetSide 2
# 1321                  AOD_AenKenji              Private  PlanetSide 2
# 1322                AOD_afk4COFFEE              Recruit  PlanetSide 2
# 1323                   AOD_alconds  Private First Class  PlanetSide 2
# 1324              AOD_AlexDeadpool              Private  PlanetSide 2
# 1325              AOD_Alpha0fOmnia                Cadet  PlanetSide 2
# 1326                     AOD_Amesy  Private First Class  PlanetSide 2
# 1327             AOD_AmorousDonkey              Private  PlanetSide 2
# 1328                   AOD_An1malz              Recruit  PlanetSide 2
# 1329               AOD_Andronovich  Private First Class  PlanetSide 2
# 1330                    AOD_Anetle              Recruit  PlanetSide 2
# 1331                AOD_Anomaly187                Cadet  PlanetSide 2
# 1332                AOD_Antonius86              Private  PlanetSide 2
# 1333          AOD_ApplyMoreBullets                Cadet  PlanetSide 2
# 1334            AOD_ArcadianTerran              Recruit  PlanetSide 2
# 1335                 AOD_ArkhanRed  Private First Class  PlanetSide 2
# 1336                  AOD_AsCougar                Cadet  PlanetSide 2
# 1337                  AOD_Aserfweg              Recruit  PlanetSide 2
# 1338               AOD_AssaultUnit              Recruit  PlanetSide 2
# 1339                   AOD_Atriarc              Recruit  PlanetSide 2
# 1340                 AOD_Audio5urf                Cadet  PlanetSide 2
# 1341                   AOD_Autoaim  Private First Class  PlanetSide 2
# 1342               AOD_AveryArsten                Cadet  PlanetSide 2
# 1343                     AOD_Avoss  Private First Class  PlanetSide 2
# 1344                     AOD_Avvri                Cadet  PlanetSide 2
# 1345              AOD_Azhattington                Cadet  PlanetSide 2
# 1346                  AOD_Bashhhhh              Recruit  PlanetSide 2
# 1347                 AOD_Bazizanab              Recruit  PlanetSide 2
# 1348                 AOD_BazookaQc              Recruit  PlanetSide 2
# 1349                  AOD_BBQDave7  Private First Class  PlanetSide 2
# 1350                   AOD_Beast02                Cadet  PlanetSide 2
# 1351                 AOD_BeaverBox              Recruit  PlanetSide 2
# 1352                    AOD_Begong  Private First Class  PlanetSide 2
# 1353               AOD_BellaSomnus              Recruit  PlanetSide 2
# 1354                 AOD_Billy3344                Cadet  PlanetSide 2
# 1355                 AOD_Bishop120              Private  PlanetSide 2
# 1356               AOD_Blackhawksi  Private First Class  PlanetSide 2
# 1357  AOD_BlackJackIsNotASmartPony              Recruit  PlanetSide 2
# 1358             AOD_BladeRunnerTR              Recruit  PlanetSide 2
#
#         Status   Join Date Last Activity          GameName
# 530     Active  09-30-2015    02-01-2017      renegadeecho
# 566     Active  03-05-2015    01-31-2017      smokinbarrel
# 837     Active  03-19-2013    11-25-2016        rednecksod
# 1039    Active  11-23-2014    01-29-2017         adeadhead
# 1185    Active  12-28-2015    01-23-2017       mikearuant2
# 1248    Active  06-27-2016    01-29-2017      shadowsheeps
# 1310    Active  07-06-2016    01-08-2017            0znex0
# 1311    Active  09-05-2015    01-17-2017             2k301
# 1312    Active  12-30-2016    01-01-2017               nan
# 1313    Active  02-15-2013    01-08-2017       3423collins
# 1314    Active  07-30-2016    12-11-2016               nan
# 1315    Active  11-03-2014    01-27-2017         40ozmouse
# 1316    Active  12-18-2016    01-01-2017               nan
# 1317    Active  11-16-2016    01-01-2017               nan
# 1318    Active  12-04-2014    01-02-2017     achesandpains
# 1319    Active  01-28-2015    02-01-2017          adapt1ve
# 1320    Active  05-24-2014    01-01-2017               nan
# 1321    Active  10-27-2013    01-31-2017          aenkenji
# 1322    Active  12-30-2016    01-05-2017               nan
# 1323    Active  02-15-2016    02-01-2017           alconds
# 1324    Active  06-25-2013    02-01-2017      alexdeadpool
# 1325    Active  10-16-2016    12-21-2016               nan
# 1326    Active  09-05-2013    02-02-2017               nan
# 1327    Active  05-27-2016    01-31-2017               nan
# 1328    Active  02-07-2014    01-15-2017               nan
# 1329    Active  11-12-2014    01-30-2017       andronovich
# 1330    Active  10-17-2016    01-09-2017               nan
# 1331    Active  06-03-2016    01-29-2017               nan
# 1332    Active  07-05-2015    02-01-2017        antonius86
# 1333    Active  05-01-2016    02-01-2017  applymorebullets
# 1334    Active  10-06-2014    01-28-2017               nan
# 1335    Active  08-29-2016    01-30-2017               nan
# 1336    Active  07-01-2016    01-29-2017          ascougar
# 1337    Active  11-20-2016    12-27-2016               nan
# 1338    Active  05-16-2016    12-06-2016       assaultunit
# 1339    Active  05-30-2015    02-02-2017               nan
# 1340    Active  04-27-2014    12-27-2016               nan
# 1341    Active  01-20-2013    01-31-2017           autoaim
# 1342    Active  03-03-2016    01-29-2017       averyarsten
# 1343    Active  01-09-2013    01-24-2017             avoss
# 1344    Active  08-23-2016    12-30-2016               nan
# 1345    Active  09-01-2015    02-01-2017               nan
# 1346    Active  01-22-2017    01-25-2017               nan
# 1347    Active  01-19-2017    02-01-2017               nan
# 1348    Active  01-18-2017    01-26-2017               nan
# 1349    Active  11-27-2014    01-17-2017          bbqdave7
# 1350    Active  12-22-2016    02-02-2017               nan
# 1351    Active  04-16-2016    01-05-2017               nan
# 1352    Active  08-03-2015    02-01-2017               nan
# 1353  On Leave  01-24-2016    09-15-2016       bellasomnus
# 1354    Active  11-10-2013    01-20-2017               nan
# 1355    Active  06-12-2016    01-08-2017         bishop120
# 1356    Active  07-30-2014    01-31-2017       blackhawksi
# 1357    Active  01-22-2017    01-30-2017               nan
# 1358    Active  09-30-2016    02-01-2017               nan

# %%
newShowRoster1 = newShowRoster.merge(nameDF, left_on='GameName', right_on='name', how='outer')

# %%
#newShowRoster5.info()

# %%
#newShowRoster5.to_csv('planetside2mems022017.csv', index=None)

# %%
from IPython.display import Javascript
js_download = """
var csv = '%s';

var filename = 'results.csv';
var blob = new Blob([csv], { type: 'text/csv;charset=utf-8;' });
if (navigator.msSaveBlob) { // IE 10+
    navigator.msSaveBlob(blob, filename);
} else {
    var link = document.createElement("a");
    if (link.download !== undefined) { // feature detection
        // Browsers that support HTML5 download attribute
        var url = URL.createObjectURL(blob);
        link.setAttribute("href", url);
        link.setAttribute("download", filename);
        link.style.visibility = 'hidden';
        document.body.appendChild(link);
        link.click();
        document.body.removeChild(link);
    }
}
""" % newShowRoster1.to_csv(index=False).replace('\n','\\n').replace("'","\'")

Javascript(js_download)
